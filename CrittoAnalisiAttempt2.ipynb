ZZZ]]\\\],\mZk.m\],mZZZk.mZ]ZZZZZZZZZZZZZ]\\\]ZZZZZZZZZZZZ]ZZZ]ZZZ,mZZZk.mZZ],mZZZk.m],mZZZk.mZ]\,\mZk.m\]]\\],mZZZZZZk.m],mZZZk.m]\,\mZk.m]\],mZZZZZk.mZ]\\\]ZZ,\mZZk.m]\\\],mZZZk.m]\,mZZZZk.m\],\\mZk.m]ZZZZZZZZZZZ]Z,mZZZk.mZZ],mZZZk.m]Z,\mZk.mZ]Z]],mZZZZZk.m],\mZZk.m\]\\],mZZZk.m]\,mZZZZk.mZ]\\],mZZZZZk.m]\,mZZZZk.m]ZZZZ,mZZZ
# ...

# %%
slot = ""
CryArray = []
i = 0
for x in CryText:
    i=i+1
    slot = slot + x 
    if i==2: 
        i=0
        CryArray.append(slot) 
        slot=""
for x in CryArray: 
    print(x)
# Out:
# ,\
# mZ
# k.
# m\
# ],
# \\
# mZ
# k.
# m]
# ZZ
# ]Z
# ZZ
# ZZ
# ZZ
# Z]
# ZZ
# ],
# \m
# Zk
# .m
# \]
# Z,
# mZ
# ZZ
# k.
# m]
# ZZ
# ZZ
# Z]
# Z]
# ,\
# mZ
# k.
# m\
# ]Z
# Z,
# \m
# ZZ
# k.
# m]
# \\
# ]Z
# Z]
# ]\
# ]\
# ,\
# mZ
# k.
# m]
# ,\
# mZ
# k.
# m]
# m,
# \m
# Zk
# .m
# \]
# ,\
# mZ
# ZZ
# k.
# m]
# ZZ
# ZZ
# ZZ
# ZZ
# ZZ
# ZZ
# Z]
# \\
# ]\
# \]
# ZZ
# ZZ
# ZZ
# ZZ
# ZZ
# ZZ
# ]\
# \]
# ZZ
# ZZ
# ZZ
# ZZ
# Z]
# ZZ
# ZZ
# ZZ
# ]Z
# ZZ
# ,m
# ZZ
# Zk
# .m
# ],
# mZ
# ZZ
# k.
# m]
# \\
# \]
# Z,
# mZ
# ZZ
# k.
# m]
# ZZ
# ZZ
# Z]
# \]
# \,
# \m
# Zk
# .m
# ]\
# ,m
# ZZ
# ZZ
# k.
# m]
# \\
# \]
# ,\
# mZ
# k.
# m\
# ],
# mZ
# ZZ
# k.
# mZ
# ]\
# ,\
# mZ
# k.
# m\
# ]\
# ]\
# \\
# ],
# \m
# Zk
# .m
# \]
# ]Z
# ,m
# ZZ
# Zk
# .m
# ZZ
# ]Z
# ,\
# mZ
# k.
# m]
# ,\
# \m
# Zk
# .m
# ]Z
# ,m
# ZZ
# Zk
# .m
# Z]
# mZ
# ZZ
# ZZ
# ZZ
# ZZ
# Z]
# ZZ
# ,Z
# ZZ
# Zm
# \k
# .m
# ],
# \m
# ZZ
# Zk
# .m
# ],
# ZZ
# m\
# k.
# m\
# ]\
# ,m
# ZZ
# ZZ
# k.
# m]
# ZZ
# ZZ
# ,m
# ZZ
# Zk
# .m
# ...

# %%
import collections
counter=collections.Counter(CryArray)
for x in counter :
    print( str( counter[x] ) + ' for ' + x);
# Out:
# 28 for ,\
# 76 for mZ
# 68 for k.
# 17 for m\
# 34 for ],
# 25 for \\
# 43 for m]
# 292 for ZZ
# 40 for ]Z
# 41 for Z]
# 27 for \m
# 56 for Zk
# 57 for .m
# 40 for \]
# 20 for Z,
# 34 for ]\
# 1 for m,
# 31 for ,m
# 10 for \,
# 1 for ,Z
# 1 for Zm
# 1 for \k
# 2 for ]]
# 1 for ]m

# %%
print( str( len( counter )))
# Out:
# 24

# %%
import collections
counter=collections.Counter(CryArray)
counterOrdered=counter.most_common()
i=0
for x in counterOrdered :
    print( str(x[1]) + ' founded for ' + x[0])
# Out:
# 292 founded for ZZ
# 76 founded for mZ
# 68 founded for k.
# 57 founded for .m
# 56 founded for Zk
# 43 founded for m]
# 41 founded for Z]
# 40 founded for ]Z
# 40 founded for \]
# 34 founded for ],
# 34 founded for ]\
# 31 founded for ,m
# 28 founded for ,\
# 27 founded for \m
# 25 founded for \\
# 20 founded for Z,
# 17 founded for m\
# 10 founded for \,
# 2 founded for ]]
# 1 founded for m,
# 1 founded for ,Z
# 1 founded for Zm
# 1 founded for \k
# 1 founded for ]m

# %% [markdown]
# <table>
# <tbody><tr>
# <td>
# <table class="wikitable">
#
# <tbody><tr>
# <th>Letter</th>
# <th>Code</th>
# <th>Binary
# </th></tr>
# <tr>
# <td>A</td>
# <td>aaaaa</td>
# <td>00000
# </td></tr>
# <tr>
# <td>B</td>
# <td>aaaab</td>
# <td>00001
# </td></tr>
# <tr>
# <td>C</td>
# <td>aaaba</td>
# <td>00010
# </td></tr>
# <tr>
# <td>D</td>
# <td>aaabb</td>
# <td>00011
# </td></tr>
# <tr>
# <td>E</td>
# <td>aabaa</td>
# <td>00100
# </td></tr>
# <tr>
# <td>F</td>
# <td>aabab</td>
# <td>00101
# </td></tr>
# <tr>
# <td>G</td>
# <td>aabba</td>
# <td>00110
# </td></tr>
# <tr>
# <td>H</td>
# <td>aabbb</td>
# <td>00111
# </td></tr>
# <tr>
# <td>I, J</td>
# <td>abaaa</td>
# <td>01000
# </td></tr>
# <tr>
# <td>K</td>
# <td>abaab</td>
# <td>01001
# </td></tr>
# <tr>
# <td>L</td>
# <td>ababa</td>
# <td>01010
# </td></tr>
# <tr>
# <td>M</td>
# <td>ababb</td>
# <td>01011
# </td></tr></tbody></table>
# </td>
# <td>
# <table class="wikitable">
#
# <tbody><tr>
# <th>Letter</th>
# <th>Code</th>
# <th>Binary
# </th></tr>
# <tr>
# <td>N</td>
# <td>abbaa</td>
# <td>01100
# </td></tr>
# <tr>
# <td>O</td>
# <td>abbab</td>
# <td>01101
# </td></tr>
# <tr>
# <td>P</td>
# <td>abbba</td>
# <td>01110
# </td></tr>
# <tr>
# <td>Q</td>
# <td>abbbb</td>
# <td>01111
# </td></tr>
# <tr>
# <td>R</td>
# <td>baaaa</td>
# <td>10000
# </td></tr>
# <tr>
# <td>S</td>
# <td>baaab</td>
# <td>10001
# </td></tr>
# <tr>
# <td>T</td>
# <td>baaba</td>
# <td>10010
# </td></tr>
# <tr>
# <td>U, V</td>
# <td>baabb</td>
# <td>10011
# </td></tr>
# <tr>
# <td>W</td>
# <td>babaa</td>
# <td>10100
# </td></tr>
# <tr>
# <td>X</td>
# <td>babab</td>
# <td>10101
# </td></tr>
# <tr>
# <td>Y</td>
# <td>babba</td>
# <td>10110
# </td></tr>
# <tr>
# <td>Z</td>
# <td>babbb</td>
# <td>10111
# </td></tr></tbody></table>
# </td></tr></tbody></table>

# %% [markdown]
# <table class="wikitable sortable jquery-tablesorter">
#
# <thead><tr>
# <th class="headerSort" tabindex="0" role="columnheader button" title="Ordinamento crescente">Lettera</th>
# <th class="headerSort headerSortDown" tabindex="0" role="columnheader button" title="Ordinamento crescente">Frequenza
# </th></tr></thead><tbody>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <tr>
# <td><b>e</b></td>
# <td>11.79%
# </td></tr><tr>
# <td><b>a</b></td>
# <td>11.74%
# </td></tr><tr>
# <td><b>i</b></td>
# <td>11.28%
# </td></tr><tr>
# <td><b>o</b></td>
# <td>9.83%
# </td></tr><tr>
# <td><b>n</b></td>
# <td>6.88%
# </td></tr><tr>
# <td><b>l</b></td>
# <td>6.51%
# </td></tr><tr>
# <td><b>r</b></td>
# <td>6.37%
# </td></tr><tr>
# <td><b>t</b></td>
# <td>5.62%
# </td></tr><tr>
# <td><b>s</b></td>
# <td>4.98%
# </td></tr><tr>
# <td><b>c</b></td>
# <td>4.50%
# </td></tr><tr>
# <td><b>d</b></td>
# <td>3.73%
# </td></tr><tr>
# <td><b>p</b></td>
# <td>3.05%
# </td></tr><tr>
# <td><b>u</b></td>
# <td>3.01%
# </td></tr><tr>
# <td><b>m</b></td>
# <td>2.51%
# </td></tr><tr>
# <td><b>v</b></td>
# <td>2.10%
# </td></tr><tr>
# <td><b>g</b></td>
# <td>1.64%
# </td></tr><tr>
# <td><b>h</b></td>
# <td>1.54%
# </td></tr><tr>
# <td><b>f</b></td>
# <td>0.95%
# </td></tr><tr>
# <td><b>b</b></td>
# <td>0.92%
# </td></tr><tr>
# <td><b>q</b></td>
# <td>0.51%
# </td></tr><tr>
# <td><b>z</b></td>
# <td>0.49%
# </td></tr></tbody><tfoot></tfoot></table>

# %% [markdown]
# studio sulle frequenze sillabe
# <br>
# https://pdfs.semanticscholar.org/9b28/fc469371359dcd64194a37dec0a081994000.pdf

# %%
substitutionARRAY = [];

Numbers=range(1,25);
Alphabet='ABCDEFGHIKLMNOPQRSTVWXYZ';
i=0
for x in counter.most_common(24):
    substitutionARRAY.append( ( x[0] ,str(Numbers[i]) + " ",x[1]) );
    if i==0:
        substitutionARRAY[0]=( x[0] ,"   ",x[1])
    i=i+1
for x in substitutionARRAY:
    print(x)
# Out:
# ('ZZ', '   ', 292)
# ('mZ', '2 ', 76)
# ('k.', '3 ', 68)
# ('.m', '4 ', 57)
# ('Zk', '5 ', 56)
# ('m]', '6 ', 43)
# ('Z]', '7 ', 41)
# (']Z', '8 ', 40)
# ('\\]', '9 ', 40)
# ('],', '10 ', 34)
# (']\\', '11 ', 34)
# (',m', '12 ', 31)
# (',\\', '13 ', 28)
# ('\\m', '14 ', 27)
# ('\\\\', '15 ', 25)
# ('Z,', '16 ', 20)
# ('m\\', '17 ', 17)
# ('\\,', '18 ', 10)
# (']]', '19 ', 2)
# ('m,', '20 ', 1)
# (',Z', '21 ', 1)
# ('Zm', '22 ', 1)
# ('\\k', '23 ', 1)
# (']m', '24 ', 1)

# %% [markdown]
# mappa della rarità

# %%
myCryArray=[]

for x in CryArray:
    for y in substitutionARRAY:
        if x==y[0]:
            myCryArray.append(y[1])
myCryText= ''.join(myCryArray)
print(myCryText)
# Out:
# 13 2 3 17 10 15 2 3 6    8          7    10 14 5 4 9 16 2    3 6       7 7 13 2 3 17 8 16 14    3 6 15 8 7 11 11 13 2 3 6 13 2 3 6 20 14 5 4 9 13 2    3 6                   7 15 11 9                   11 9             7          8    12    5 4 10 2    3 6 15 9 16 2    3 6       7 9 18 14 5 4 11 12       3 6 15 9 13 2 3 17 10 2    3 2 11 13 2 3 17 11 11 15 10 14 5 4 9 8 12    5 4    8 13 2 3 6 13 14 5 4 8 12    5 4 7 2             7    21    22 23 4 10 14    5 4 10    17 3 17 11 12       3 6       12    5 4 8             8       11 10 14 5 4 9 16 2    3 2 8 8          19 15 9 12    5 4 11 12       3 17 10 15 2 3 6                7 16 2    3 2 7 13 2 5 4 8 13 2 3 6 16 2 5 4 10 14    5 4    8    11 12    5 4 11 15 11 12       3 6       12    5 4 11 13 2 3 6 16 14 5 4 7 7 10 2       3 6 16 2    3 6          10 14 5 4 9    12    5 4 8             8    7 11 15 10 14 5 4 9 12    5 4 7                   7 15 9                   8    8    12    5 4    10 2    3 6 12    5 4 7 18 14 5 4 9 11 9 
# ...

# %%
SillabFrequency = [
    (["CV"],58),
    (["CVC"],15),
    (["V"],8),
    (["VC"],6),
    (["CVV"],6),
    (["CCV"],5),
]

AlphabetFrequency = [
    (["e","a","i","o"],40),
    (["n","l","r","t"],24),
    (["s","c"],10),
    (["d","p","v","m"],11),
    (["g","h"],3),
    (["f","b",],2),
    (["q","z","x","y","w"],1) 
    ]
import random;
#algoritmo per generare alfabeti:
skyLS=substitutionARRAY;
i=1
j=0
gCounter=0
for x in skyLS:
    
    #sostituiamo radomicamente con una lettera per fasce
    if  i<5 :
        tempList=AlphabetFrequency[j][0] 
        print(str(i) + ": "+str(tempList));
        randomIndex = random.randrange( len(tempList)  )
        skyLS[i]=( skyLS[i][0] , AlphabetFrequency[0][0][randomIndex] , skyLS[i][2] );
        del tempList[randomIndex]
        i=i+1
        
    elif i<9:
        if (i==5) :
            j=j+1
        tempList=AlphabetFrequency[j][0]
        print(str(i) + ": "+str(tempList));
        randomIndex = random.randrange( len(tempList)  )
        skyLS[i]=( skyLS[i][0] , AlphabetFrequency[j][0][randomIndex] , skyLS[i][2] );
        del tempList[randomIndex]
        i=i+1
    elif i<11:
        if (i==9) :
            j=j+1
        tempList=AlphabetFrequency[j][0] 
        print(str(i) + ": "+str(tempList));
        randomIndex = random.randrange( len(tempList)  )
        skyLS[i]=( skyLS[i][0] , AlphabetFrequency[j][0][randomIndex] , skyLS[i][2] );
        del tempList[randomIndex]
        i=i+1
    elif i<15:
        if (i==11) :
            j=j+1
        tempList=AlphabetFrequency[j][0] 
        print(str(i) + ": "+str(tempList));
        randomIndex = random.randrange( len(tempList)  )
        skyLS[i]=( skyLS[i][0] , AlphabetFrequency[j][0][randomIndex] , skyLS[i][2] );
        del tempList[randomIndex]
        i=i+1
    elif i<17:
        if (i==15) :
            j=j+1
        tempList=AlphabetFrequency[j][0] 
        print(str(i) + ": "+str(tempList));
        randomIndex = random.randrange( len(tempList)  )
        skyLS[i]=( skyLS[i][0] , AlphabetFrequency[j][0][randomIndex] , skyLS[i][2] );
        del tempList[randomIndex]
        i=i+1
    elif i<19:
        if (i==17) :
            j=j+1
        tempList=AlphabetFrequency[j][0] 
        print(str(i) + ": "+str(tempList));
        randomIndex = random.randrange( len(tempList)  )
        skyLS[i]=( skyLS[i][0] , AlphabetFrequency[j][0][randomIndex] , skyLS[i][2] );
        del tempList[randomIndex]
        i=i+1
    elif i<24:
        if (i==19) :
            j=j+1
        tempList=AlphabetFrequency[j][0] 
        print(str(i) + ": "+str(tempList));
        randomIndex = random.randrange( len(tempList)  )
        skyLS[i]=( skyLS[i][0] , AlphabetFrequency[j][0][randomIndex] , skyLS[i][2] );
        del tempList[randomIndex]
        i=i+1
# Out:
# 1: ['e', 'a', 'i', 'o']
# 2: ['e', 'i', 'o']
# 3: ['i', 'o']
# 4: ['i']
# 5: ['n', 'l', 'r', 't']
# 6: ['l', 'r', 't']
# 7: ['l', 't']
# 8: ['t']
# 9: ['s', 'c']
# 10: ['c']
# 11: ['d', 'p', 'v', 'm']
# 12: ['d', 'p', 'v']
# 13: ['d', 'p']
# 14: ['p']
# 15: ['g', 'h']
# 16: ['h']
# 17: ['f', 'b']
# 18: ['f']
# 19: ['q', 'z', 'x', 'y', 'w']
# 20: ['q', 'z', 'x', 'w']
# 21: ['q', 'z', 'x']
# 22: ['q', 'x']
# 23: ['x']

# %%
myCryArray=[]

for x in CryArray:
    for y in substitutionARRAY:
        if x==y[0]:
            myCryArray.append(y[1])
myCryText= ''.join(myCryArray)
print(myCryText)
# Out:
# vaehspaen   l         r   sdiotga   en      rrvaehlgd   enplrccvaenvaenydiotva   en                  rpct                  ct            r         l   m   iosa   enptga   en      rtbdiocm      enptvaehsa   eacvaehccpsdiotlm   io   lvaenvdiolm   iora            r   w   zqosd   ios   hehcm      en      m   iol            l      csdiotga   eall         fptm   iocm      ehspaen               rga   earvaiolvaengaiosd   io   l   cm   iocpcm      en      m   iocvaengdiorrsa      enga   en         sdiot   m   iol            l   rcpsdiotm   ior                  rpt                  l   l   m   io   sa   enm   iorbdiotctm         enm   iocvaentm      iorpt   vaiocpsa   enba   iotvdiol               lm   io   sa   engdiorrsa      envaiotpsa   enba   iorpsa      enba   iol   ga   en            r      rtvaehl         rgdiol               rtpcvaen      ga   enpl         csdiotga   en                  l   r   m   io   sd      enptga   eall         s   hehcvaiocpsdiotrtg   heasd   iotvaea   lga   en
# ...
